# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("LoanPrediction") \
    .getOrCreate()

# %%
df = spark.read.csv("/DATA/loan.csv", header=True, inferSchema=True)

# %%
df.na.drop().count()

# Show işlemini kullanarak DataFrame'i daha düzenli görüntüleme
df.show(truncate=False, vertical=True)
# Out:
# [Stage 1212:==================================================>   (13 + 1) / 14]
# -RECORD 0-----------------------------------------------------------------
#  id                                         | null
#  member_id                                  | null
#  loan_amnt                                  | 2500
#  funded_amnt                                | 2500
#  funded_amnt_inv                            | 2500.0
#  term                                       |  36 months
#  int_rate                                   | 13.56
#  installment                                | 84.92
#  grade                                      | C
#  sub_grade                                  | C1
#  emp_title                                  | Chef
#  emp_length                                 | 10+ years
#  home_ownership                             | RENT
#  annual_inc                                 | 55000
#  verification_status                        | Not Verified
#  issue_d                                    | Dec-2018
#  loan_status                                | Current
#  pymnt_plan                                 | n
#  url                                        | null
#  desc                                       | null
#  purpose                                    | debt_consolidation
#  title                                      | Debt consolidation
#  zip_code                                   | 109xx
#  addr_state                                 | NY
#  dti                                        | 18.24
#  delinq_2yrs                                | 0
#  earliest_cr_line                           | Apr-2001
#  inq_last_6mths                             | 1
#  mths_since_last_delinq                     | null
#  mths_since_last_record                     | 45
#  open_acc                                   | 9
#  pub_rec                                    | 1
#  revol_bal                                  | 4341
#  revol_util                                 | 10.3
#  total_acc                                  | 34
#  initial_list_status                        | w
#  out_prncp                                  | 2386.02
#  out_prncp_inv                              | 2386.02
#  total_pymnt                                | 167.02
#  total_pymnt_inv                            | 167.02
#  total_rec_prncp                            | 113.98
#  total_rec_int                              | 53.04
#  total_rec_late_fee                         | 0.0
#  recoveries                                 | 0.0
#  collection_recovery_fee                    | 0.0
#  last_pymnt_d                               | Feb-2019
#  last_pymnt_amnt                            | 84.92
#  next_pymnt_d                               | Mar-2019
#  last_credit_pull_d                         | Feb-2019
#  collections_12_mths_ex_med                 | 0
#  mths_since_last_major_derog                | null
#  policy_code                                | 1
#  application_type                           | Individual
#  annual_inc_joint                           | null
#  dti_joint                                  | null
#  verification_status_joint                  | null
#  acc_now_delinq                             | 0
#  tot_coll_amt                               | 0
#  tot_cur_bal                                | 16901
#  open_acc_6m                                | 2
#  open_act_il                                | 2
#  open_il_12m                                | 1
#  open_il_24m                                | 2
#  mths_since_rcnt_il                         | 2
#  total_bal_il                               | 12560
#  il_util                                    | 69
#  open_rv_12m                                | 2
#  open_rv_24m                                | 7
#  max_bal_bc                                 | 2137
#  all_util                                   | 28
#  total_rev_hi_lim                           | 42000
#  inq_fi                                     | 1
#  total_cu_tl                                | 11
#  inq_last_12m                               | 2
#  acc_open_past_24mths                       | 9
#  avg_cur_bal                                | 1878
#  bc_open_to_buy                             | 34360
#  bc_util                                    | 5.9
#  chargeoff_within_12_mths                   | 0.0
#  delinq_amnt                                | 0
#  mo_sin_old_il_acct                         | 140.0
#  mo_sin_old_rev_tl_op                       | 212
#  mo_sin_rcnt_rev_tl_op                      | 1
#  mo_sin_rcnt_tl                             | 1
#  mort_acc                                   | 0
#  mths_since_recent_bc                       | 1
#  mths_since_recent_bc_dlq                   | null
#  mths_since_recent_inq                      | 2
#  mths_since_recent_revol_delinq             | null
#  num_accts_ever_120_pd                      | 0
#  num_actv_bc_tl                             | 2
#  num_actv_rev_tl                            | 5
#  num_bc_sats                                | 3
#  num_bc_tl                                  | 3
#  num_il_tl                                  | 16
#  num_op_rev_tl                              | 7
#  num_rev_accts                              | 18
#  num_rev_tl_bal_gt_0                        | 5
#  num_sats                                   | 9
#  num_tl_120dpd_2m                           | 0
#  num_tl_30dpd                               | 0
#  num_tl_90g_dpd_24m                         | 0
#  num_tl_op_past_12m                         | 3
#  pct_tl_nvr_dlq                             | 100.0
#  percent_bc_gt_75                           | 0.0
#  pub_rec_bankruptcies                       | 1
#  tax_liens                                  | 0
#  tot_hi_cred_lim                            | 60124
#  total_bal_ex_mort                          | 16901
#  total_bc_limit                             | 36500
#  total_il_high_credit_limit                 | 18124
#  revol_bal_joint                            | null
#  sec_app_earliest_cr_line                   | null
#  sec_app_inq_last_6mths                     | null
#  sec_app_mort_acc                           | null
#  sec_app_open_acc                           | null
#  sec_app_revol_util                         | null
#  sec_app_open_act_il                        | null
#  sec_app_num_rev_accts                      | null
#  sec_app_chargeoff_within_12_mths           | null
#  sec_app_collections_12_mths_ex_med         | null
#  sec_app_mths_since_last_major_derog        | null
#  hardship_flag                              | N
#  hardship_type                              | null
#  hardship_reason                            | null
#  hardship_status                            | null
#  deferral_term                              | null
#  hardship_amount                            | null
#  hardship_start_date                        | null
#  hardship_end_date                          | null
#  payment_plan_start_date                    | null
#  hardship_length                            | null
#  hardship_dpd                               | null
#  hardship_loan_status                       | null
#  orig_projected_additional_accrued_interest | null
#  hardship_payoff_balance_amount             | null
#  hardship_last_payment_amount               | null
#  disbursement_method                        | Cash
#  debt_settlement_flag                       | N
#  debt_settlement_flag_date                  | null
#  settlement_status                          | null
#  settlement_date                            | null
#  settlement_amount                          | null
#  settlement_percentage                      | null
#  settlement_term                            | null
# -RECORD 1-----------------------------------------------------------------
#  id                                         | null
#  member_id                                  | null
#  loan_amnt                                  | 30000
#  funded_amnt                                | 30000
#  funded_amnt_inv                            | 30000.0
#  term                                       |  60 months
#  int_rate                                   | 18.94
#  installment                                | 777.23
#  grade                                      | D
#  sub_grade                                  | D2
#  emp_title                                  | Postmaster
#  emp_length                                 | 10+ years
#  home_ownership                             | MORTGAGE
#  annual_inc                                 | 90000
#  verification_status                        | Source Verified
#  issue_d                                    | Dec-2018
#  loan_status                                | Current
#  pymnt_plan                                 | n
#  url                                        | null
#  desc                                       | null
#  purpose                                    | debt_consolidation
#  title                                      | Debt consolidation
#  zip_code                                   | 713xx
#  addr_state                                 | LA
#  dti                                        | 26.52
#  delinq_2yrs                                | 0
#  earliest_cr_line                           | Jun-1987
#  inq_last_6mths                             | 0
#  mths_since_last_delinq                     | 71
#  mths_since_last_record                     | 75
#  open_acc                                   | 13
#  pub_rec                                    | 1
#  revol_bal                                  | 12315
#  revol_util                                 | 24.2
#  total_acc                                  | 44
#  initial_list_status                        | w
#  out_prncp                                  | 29387.75
#  out_prncp_inv                              | 29387.75
#  total_pymnt                                | 1507.11
#  total_pymnt_inv                            | 1507.11
#  total_rec_prncp                            | 612.25
#  total_rec_int                              | 894.86
#  total_rec_late_fee                         | 0.0
#  recoveries                                 | 0.0
#  collection_recovery_fee                    | 0.0
#  last_pymnt_d                               | Feb-2019
#  last_pymnt_amnt                            | 777.23
#  next_pymnt_d                               | Mar-2019
#  last_credit_pull_d                         | Feb-2019
#  collections_12_mths_ex_med                 | 0
#  mths_since_last_major_derog                | null
#  policy_code                                | 1
#  application_type                           | Individual
#  annual_inc_joint                           | null
#  dti_joint                                  | null
#  verification_status_joint                  | null
#  acc_now_delinq                             | 0
#  tot_coll_amt                               | 1208
#  tot_cur_bal                                | 321915
#  open_acc_6m                                | 4
#  open_act_il                                | 4
#  open_il_12m                                | 2
#  open_il_24m                                | 3
#  mths_since_rcnt_il                         | 3
#  total_bal_il                               | 87153
#  il_util                                    | 88
#  open_rv_12m                                | 4
#  open_rv_24m                                | 5
#  max_bal_bc                                 | 998
#  all_util                                   | 57
#  total_rev_hi_lim                           | 50800
#  inq_fi                                     | 2
#  total_cu_tl                                | 15
#  inq_last_12m                               | 2
#  acc_open_past_24mths                       | 10
#  avg_cur_bal                                | 24763
#  bc_open_to_buy                             | 13761
#  bc_util                                    | 8.3
#  chargeoff_within_12_mths                   | 0.0
#  delinq_amnt                                | 0
#  mo_sin_old_il_acct                         | 163.0
#  mo_sin_old_rev_tl_op                       | 378
#  mo_sin_rcnt_rev_tl_op                      | 4
#  mo_sin_rcnt_tl                             | 3
#  mort_acc                                   | 3
#  mths_since_recent_bc                       | 4
#  mths_since_recent_bc_dlq                   | null
#  mths_since_recent_inq                      | 4
#  mths_since_recent_revol_delinq             | null
#  num_accts_ever_120_pd                      | 0
#  num_actv_bc_tl                             | 2
#  num_actv_rev_tl                            | 4
#  num_bc_sats                                | 4
#  num_bc_tl                                  | 9
#  num_il_tl                                  | 27
#  num_op_rev_tl                              | 8
#  num_rev_accts                              | 14
#  num_rev_tl_bal_gt_0                        | 4
#  num_sats                                   | 13
#  num_tl_120dpd_2m                           | 0
#  num_tl_30dpd                               | 0
#  num_tl_90g_dpd_24m                         | 0
#  num_tl_op_past_12m                         | 6
#  pct_tl_nvr_dlq                             | 95.0
#  percent_bc_gt_75                           | 0.0
#  pub_rec_bankruptcies                       | 1
#  tax_liens                                  | 0
#  tot_hi_cred_lim                            | 372872
#  total_bal_ex_mort                          | 99468
#  total_bc_limit                             | 15000
#  total_il_high_credit_limit                 | 94072
#  revol_bal_joint                            | null
#  sec_app_earliest_cr_line                   | null
#  sec_app_inq_last_6mths                     | null
#  sec_app_mort_acc                           | null
#  sec_app_open_acc                           | null
#  sec_app_revol_util                         | null
#  sec_app_open_act_il                        | null
#  sec_app_num_rev_accts                      | null
#  sec_app_chargeoff_within_12_mths           | null
#  sec_app_collections_12_mths_ex_med         | null
#  sec_app_mths_since_last_major_derog        | null
#  hardship_flag                              | N
#  hardship_type                              | null
#  hardship_reason                            | null
#  hardship_status                            | null
#  deferral_term                              | null
#  hardship_amount                            | null
#  hardship_start_date                        | null
#  hardship_end_date                          | null
#  payment_plan_start_date                    | null
#  hardship_length                            | null
#  hardship_dpd                               | null
#  hardship_loan_status                       | null
#  orig_projected_additional_accrued_interest | null
#  hardship_payoff_balance_amount             | null
#  hardship_last_payment_amount               | null
#  disbursement_method                        | Cash
#  debt_settlement_flag                       | N
#  debt_settlement_flag_date                  | null
#  settlement_status                          | null
#  settlement_date                            | null
#  settlement_amount                          | null
#  settlement_percentage                      | null
#  settlement_term                            | null
# -RECORD 2-----------------------------------------------------------------
#  id                                         | null
#  member_id                                  | null
#  loan_amnt                                  | 5000
#  funded_amnt                                | 5000
#  funded_amnt_inv                            | 5000.0
#  term                                       |  36 months
#  int_rate                                   | 17.97
#  installment                                | 180.69
#  grade                                      | D
#  sub_grade                                  | D1
#  emp_title                                  | Administrative
#  emp_length                                 | 6 years
#  home_ownership                             | MORTGAGE
#  annual_inc                                 | 59280
#  verification_status                        | Source Verified
#  issue_d                                    | Dec-2018
#  loan_status                                | Current
#  pymnt_plan                                 | n
#  url                                        | null
#  desc                                       | null
#  purpose                                    | debt_consolidation
#  title                                      | Debt consolidation
#  zip_code                                   | 490xx
#  addr_state                                 | MI
#  dti                                        | 10.51
#  delinq_2yrs                                | 0
#  earliest_cr_line                           | Apr-2011
#  inq_last_6mths                             | 0
#  mths_since_last_delinq                     | null
#  mths_since_last_record                     | null
#  open_acc                                   | 8
#  pub_rec                                    | 0
#  revol_bal                                  | 4599
#  revol_util                                 | 19.1
#  total_acc                                  | 13
#  initial_list_status                        | w
#  out_prncp                                  | 4787.21
#  out_prncp_inv                              | 4787.21
#  total_pymnt                                | 353.89
#  total_pymnt_inv                            | 353.89
#  total_rec_prncp                            | 212.79
#  total_rec_int                              | 141.10
#  total_rec_late_fee                         | 0.0
#  recoveries                                 | 0.0
#  collection_recovery_fee                    | 0.0
#  last_pymnt_d                               | Feb-2019
#  last_pymnt_amnt                            | 180.69
#  next_pymnt_d                               | Mar-2019
#  last_credit_pull_d                         | Feb-2019
#  collections_12_mths_ex_med                 | 0
#  mths_since_last_major_derog                | null
#  policy_code                                | 1
#  application_type                           | Individual
#  annual_inc_joint                           | null
#  dti_joint                                  | null
#  verification_status_joint                  | null
#  acc_now_delinq                             | 0
#  tot_coll_amt                               | 0
#  tot_cur_bal                                | 110299
#  open_acc_6m                                | 0
#  open_act_il                                | 1
#  open_il_12m                                | 0
#  open_il_24m                                | 2
#  mths_since_rcnt_il                         | 14
#  total_bal_il                               | 7150
#  il_util                                    | 72
#  open_rv_12m                                | 0
#  open_rv_24m                                | 2
#  max_bal_bc                                 | 0
#  all_util                                   | 35
#  total_rev_hi_lim                           | 24100
#  inq_fi                                     | 1
#  total_cu_tl                                | 5
#  inq_last_12m                               | 0
#  acc_open_past_24mths                       | 4
#  avg_cur_bal                                | 18383
#  bc_open_to_buy                             | 13800
#  bc_util                                    | 0
#  chargeoff_within_12_mths                   | 0.0
#  delinq_amnt                                | 0
#  mo_sin_old_il_acct                         | 87.0
#  mo_sin_old_rev_tl_op                       | 92
#  mo_sin_rcnt_rev_tl_op                      | 15
#  mo_sin_rcnt_tl                             | 14
#  mort_acc                                   | 2
#  mths_since_recent_bc                       | 77
#  mths_since_recent_bc_dlq                   | null
#  mths_since_recent_inq                      | 14
#  mths_since_recent_revol_delinq             | null
#  num_accts_ever_120_pd                      | 0
#  num_actv_bc_tl                             | 0
#  num_actv_rev_tl                            | 3
#  num_bc_sats                                | 3
#  num_bc_tl                                  | 3
#  num_il_tl                                  | 4
#  num_op_rev_tl                              | 6
#  num_rev_accts                              | 7
#  num_rev_tl_bal_gt_0                        | 3
#  num_sats                                   | 8
#  num_tl_120dpd_2m                           | 0
#  num_tl_30dpd                               | 0
#  num_tl_90g_dpd_24m                         | 0
#  num_tl_op_past_12m                         | 0
#  pct_tl_nvr_dlq                             | 100.0
#  percent_bc_gt_75                           | 0.0
#  pub_rec_bankruptcies                       | 0
#  tax_liens                                  | 0
#  tot_hi_cred_lim                            | 136927
#  total_bal_ex_mort                          | 11749
#  total_bc_limit                             | 13800
#  total_il_high_credit_limit                 | 10000
#  revol_bal_joint                            | null
#  sec_app_earliest_cr_line                   | null
#  sec_app_inq_last_6mths                     | null
#  sec_app_mort_acc                           | null
#  sec_app_open_acc                           | null
#  sec_app_revol_util                         | null
#  sec_app_open_act_il                        | null
#  sec_app_num_rev_accts                      | null
#  sec_app_chargeoff_within_12_mths           | null
#  sec_app_collections_12_mths_ex_med         | null
#  sec_app_mths_since_last_major_derog        | null
#  hardship_flag                              | N
#  hardship_type                              | null
#  hardship_reason                            | null
#  hardship_status                            | null
#  deferral_term                              | null
#  hardship_amount                            | null
#  hardship_start_date                        | null
#  hardship_end_date                          | null
#  payment_plan_start_date                    | null
#  hardship_length                            | null
#  hardship_dpd                               | null
#  hardship_loan_status                       | null
#  orig_projected_additional_accrued_interest | null
#  hardship_payoff_balance_amount             | null
#  hardship_last_payment_amount               | null
#  disbursement_method                        | Cash
#  debt_settlement_flag                       | N
#  debt_settlement_flag_date                  | null
#  settlement_status                          | null
#  settlement_date                            | null
#  settlement_amount                          | null
#  settlement_percentage                      | null
#  settlement_term                            | null
# -RECORD 3-----------------------------------------------------------------
#  id                                         | null
#  member_id                                  | null
#  loan_amnt                                  | 4000
#  funded_amnt                                | 4000
#  funded_amnt_inv                            | 4000.0
#  term                                       |  36 months
#  int_rate                                   | 18.94
#  installment                                | 146.51
#  grade                                      | D
#  sub_grade                                  | D2
#  emp_title                                  | IT Supervisor
#  emp_length                                 | 10+ years
#  home_ownership                             | MORTGAGE
#  annual_inc                                 | 92000
#  verification_status                        | Source Verified
#  issue_d                                    | Dec-2018
#  loan_status                                | Current
#  pymnt_plan                                 | n
#  url                                        | null
#  desc                                       | null
#  purpose                                    | debt_consolidation
#  title                                      | Debt consolidation
#  zip_code                                   | 985xx
#  addr_state                                 | WA
#  dti                                        | 16.74
#  delinq_2yrs                                | 0
#  earliest_cr_line                           | Feb-2006
#  inq_last_6mths                             | 0
#  mths_since_last_delinq                     | null
#  mths_since_last_record                     | null
#  open_acc                                   | 10
#  pub_rec                                    | 0
#  revol_bal                                  | 5468
#  revol_util                                 | 78.1
#  total_acc                                  | 13
#  initial_list_status                        | w
#  out_prncp                                  | 3831.93
#  out_prncp_inv                              | 3831.93
#  total_pymnt                                | 286.71
#  total_pymnt_inv                            | 286.71
#  total_rec_prncp                            | 168.07
#  total_rec_int                              | 118.64
#  total_rec_late_fee                         | 0.0
#  recoveries                                 | 0.0
#  collection_recovery_fee                    | 0.0
#  last_pymnt_d                               | Feb-2019
#  last_pymnt_amnt                            | 146.51
#  next_pymnt_d                               | Mar-2019
#  last_credit_pull_d                         | Feb-2019
#  collections_12_mths_ex_med                 | 0
#  mths_since_last_major_derog                | null
#  policy_code                                | 1
#  application_type                           | Individual
#  annual_inc_joint                           | null
#  dti_joint                                  | null
#  verification_status_joint                  | null
#  acc_now_delinq                             | 0
#  tot_coll_amt                               | 686
#  tot_cur_bal                                | 305049
#  open_acc_6m                                | 1
#  open_act_il                                | 5
#  open_il_12m                                | 3
#  open_il_24m                                | 5
#  mths_since_rcnt_il                         | 5
#  total_bal_il                               | 30683
#  il_util                                    | 68
#  open_rv_12m                                | 0
#  open_rv_24m                                | 0
#  max_bal_bc                                 | 3761
#  all_util                                   | 70
#  total_rev_hi_lim                           | 7000
#  inq_fi                                     | 2
#  total_cu_tl                                | 4
#  inq_last_12m                               | 3
#  acc_open_past_24mths                       | 5
#  avg_cur_bal                                | 30505
#  bc_open_to_buy                             | 1239
#  bc_util                                    | 75.2
#  chargeoff_within_12_mths                   | 0.0
#  delinq_amnt                                | 0
#  mo_sin_old_il_acct                         | 62.0
#  mo_sin_old_rev_tl_op                       | 154
#  mo_sin_rcnt_rev_tl_op                      | 64
#  mo_sin_rcnt_tl                             | 5
#  mort_acc                                   | 3
#  mths_since_recent_bc                       | 64
#  mths_since_recent_bc_dlq                   | null
#  mths_since_recent_inq                      | 5
#  mths_since_recent_revol_delinq             | null
#  num_accts_ever_120_pd                      | 0
#  num_actv_bc_tl                             | 1
#  num_actv_rev_tl                            | 2
#  num_bc_sats                                | 1
#  num_bc_tl                                  | 2
#  num_il_tl                                  | 7
#  num_op_rev_tl                              | 2
#  num_rev_accts                              | 3
#  num_rev_tl_bal_gt_0                        | 2
#  num_sats                                   | 10
#  num_tl_120dpd_2m                           | 0
#  num_tl_30dpd                               | 0
#  num_tl_90g_dpd_24m                         | 0
#  num_tl_op_past_12m                         | 3
#  pct_tl_nvr_dlq                             | 100.0
#  percent_bc_gt_75                           | 100.0
#  pub_rec_bankruptcies                       | 0
#  tax_liens                                  | 0
#  tot_hi_cred_lim                            | 385183
#  total_bal_ex_mort                          | 36151
#  total_bc_limit                             | 5000
#  total_il_high_credit_limit                 | 44984
#  revol_bal_joint                            | null
#  sec_app_earliest_cr_line                   | null
#  sec_app_inq_last_6mths                     | null
#  sec_app_mort_acc                           | null
#  sec_app_open_acc                           | null
#  sec_app_revol_util                         | null
#  sec_app_open_act_il                        | null
#  sec_app_num_rev_accts                      | null
#  sec_app_chargeoff_within_12_mths           | null
#  sec_app_collections_12_mths_ex_med         | null
#  sec_app_mths_since_last_major_derog        | null
#  hardship_flag                              | N
#  hardship_type                              | null
#  hardship_reason                            | null
#  hardship_status                            | null
#  deferral_term                              | null
#  hardship_amount                            | null
#  hardship_start_date                        | null
#  hardship_end_date                          | null
#  payment_plan_start_date                    | null
#  hardship_length                            | null
#  hardship_dpd                               | null
#  hardship_loan_status                       | null
#  orig_projected_additional_accrued_interest | null
#  hardship_payoff_balance_amount             | null
#  hardship_last_payment_amount               | null
#  disbursement_method                        | Cash
#  debt_settlement_flag                       | N
#  debt_settlement_flag_date                  | null
#  settlement_status                          | null
#  settlement_date                            | null
#  settlement_amount                          | null
#  settlement_percentage                      | null
#  settlement_term                            | null
# -RECORD 4-----------------------------------------------------------------
#  id                                         | null
#  member_id                                  | null
#  loan_amnt                                  | 30000
#  funded_amnt                                | 30000
#  funded_amnt_inv                            | 30000.0
#  term                                       |  60 months
#  int_rate                                   | 16.14
#  installment                                | 731.78
#  grade                                      | C
#  sub_grade                                  | C4
#  emp_title                                  | Mechanic
#  emp_length                                 | 10+ years
#  home_ownership                             | MORTGAGE
#  annual_inc                                 | 57250
#  verification_status                        | Not Verified
#  issue_d                                    | Dec-2018
#  loan_status                                | Current
#  pymnt_plan                                 | n
#  url                                        | null
#  desc                                       | null
#  purpose                                    | debt_consolidation
#  title                                      | Debt consolidation
#  zip_code                                   | 212xx
#  addr_state                                 | MD
#  dti                                        | 26.35
#  delinq_2yrs                                | 0
#  earliest_cr_line                           | Dec-2000
#  inq_last_6mths                             | 0
#  mths_since_last_delinq                     | null
#  mths_since_last_record                     | null
#  open_acc                                   | 12
#  pub_rec                                    | 0
#  revol_bal                                  | 829
#  revol_util                                 | 3.6
#  total_acc                                  | 26
#  initial_list_status                        | w
#  out_prncp                                  | 29339.02
#  out_prncp_inv                              | 29339.02
#  total_pymnt                                | 1423.21
#  total_pymnt_inv                            | 1423.21
#  total_rec_prncp                            | 660.98
#  total_rec_int                              | 762.23
#  total_rec_late_fee                         | 0.0
#  recoveries                                 | 0.0
#  collection_recovery_fee                    | 0.0
#  last_pymnt_d                               | Feb-2019
#  last_pymnt_amnt                            | 731.78
#  next_pymnt_d                               | Mar-2019
#  last_credit_pull_d                         | Feb-2019
#  collections_12_mths_ex_med                 | 0
#  mths_since_last_major_derog                | null
#  policy_code                                | 1
#  application_type                           | Individual
# ...
#  chargeoff_within_12_mths                   | 0.0
#  delinq_amnt                                | 0
#  mo_sin_old_il_acct                         | 136.0
#  mo_sin_old_rev_tl_op                       | 146
#  mo_sin_rcnt_rev_tl_op                      | 12
#  mo_sin_rcnt_tl                             | 4
#  mort_acc                                   | 2
#  mths_since_recent_bc                       | 12
#  mths_since_recent_bc_dlq                   | 48
#  mths_since_recent_inq                      | 4
#  mths_since_recent_revol_delinq             | 8
#  num_accts_ever_120_pd                      | 2
#  num_actv_bc_tl                             | 2
#  num_actv_rev_tl                            | 4
#  num_bc_sats                                | 2
#  num_bc_tl                                  | 5
#  num_il_tl                                  | 24
#  num_op_rev_tl                              | 6
#  num_rev_accts                              | 10
#  num_rev_tl_bal_gt_0                        | 4
#  num_sats                                   | 13
#  num_tl_120dpd_2m                           | 0
#  num_tl_30dpd                               | 0
#  num_tl_90g_dpd_24m                         | 0
#  num_tl_op_past_12m                         | 2
#  pct_tl_nvr_dlq                             | 86.5
#  percent_bc_gt_75                           | 100.0
#  pub_rec_bankruptcies                       | 0
#  tax_liens                                  | 0
#  tot_hi_cred_lim                            | 444217
#  total_bal_ex_mort                          | 266754
#  total_bc_limit                             | 13500
#  total_il_high_credit_limit                 | 239338
#  revol_bal_joint                            | null
#  sec_app_earliest_cr_line                   | null
#  sec_app_inq_last_6mths                     | null
#  sec_app_mort_acc                           | null
#  sec_app_open_acc                           | null
#  sec_app_revol_util                         | null
#  sec_app_open_act_il                        | null
#  sec_app_num_rev_accts                      | null
#  sec_app_chargeoff_within_12_mths           | null
#  sec_app_collections_12_mths_ex_med         | null
#  sec_app_mths_since_last_major_derog        | null
#  hardship_flag                              | N
#  hardship_type                              | null
#  hardship_reason                            | null
#  hardship_status                            | null
#  deferral_term                              | null
#  hardship_amount                            | null
#  hardship_start_date                        | null
#  hardship_end_date                          | null
#  payment_plan_start_date                    | null
#  hardship_length                            | null
#  hardship_dpd                               | null
#  hardship_loan_status                       | null
#  orig_projected_additional_accrued_interest | null
#  hardship_payoff_balance_amount             | null
#  hardship_last_payment_amount               | null
#  disbursement_method                        | Cash
#  debt_settlement_flag                       | N
#  debt_settlement_flag_date                  | null
#  settlement_status                          | null
#  settlement_date                            | null
#  settlement_amount                          | null
#  settlement_percentage                      | null
#  settlement_term                            | null
# -RECORD 19----------------------------------------------------------------
#  id                                         | null
#  member_id                                  | null
#  loan_amnt                                  | 13000
#  funded_amnt                                | 13000
#  funded_amnt_inv                            | 13000.0
#  term                                       |  60 months
#  int_rate                                   | 14.47
#  installment                                | 305.67
#  grade                                      | C
#  sub_grade                                  | C2
#  emp_title                                  | Stationary Engineer
#  emp_length                                 | 10+ years
#  home_ownership                             | MORTGAGE
#  annual_inc                                 | 75000
#  verification_status                        | Not Verified
#  issue_d                                    | Dec-2018
#  loan_status                                | Current
#  pymnt_plan                                 | n
#  url                                        | null
#  desc                                       | null
#  purpose                                    | debt_consolidation
#  title                                      | Debt consolidation
#  zip_code                                   | 741xx
#  addr_state                                 | OK
#  dti                                        | 26.16
#  delinq_2yrs                                | 0
#  earliest_cr_line                           | Feb-2001
#  inq_last_6mths                             | 1
#  mths_since_last_delinq                     | null
#  mths_since_last_record                     | null
#  open_acc                                   | 9
#  pub_rec                                    | 0
#  revol_bal                                  | 15551
#  revol_util                                 | 58.2
#  total_acc                                  | 13
#  initial_list_status                        | w
#  out_prncp                                  | 12700.38
#  out_prncp_inv                              | 12700.38
#  total_pymnt                                | 595.66
#  total_pymnt_inv                            | 595.66
#  total_rec_prncp                            | 299.62
#  total_rec_int                              | 296.04
#  total_rec_late_fee                         | 0.0
#  recoveries                                 | 0.0
#  collection_recovery_fee                    | 0.0
#  last_pymnt_d                               | Feb-2019
#  last_pymnt_amnt                            | 305.67
#  next_pymnt_d                               | Mar-2019
#  last_credit_pull_d                         | Feb-2019
#  collections_12_mths_ex_med                 | 0
#  mths_since_last_major_derog                | null
#  policy_code                                | 1
#  application_type                           | Individual
#  annual_inc_joint                           | null
#  dti_joint                                  | null
#  verification_status_joint                  | null
#  acc_now_delinq                             | 0
#  tot_coll_amt                               | 0
#  tot_cur_bal                                | 131400
#  open_acc_6m                                | 0
#  open_act_il                                | 5
#  open_il_12m                                | 1
#  open_il_24m                                | 4
#  mths_since_rcnt_il                         | 10
#  total_bal_il                               | 35369
#  il_util                                    | 70
#  open_rv_12m                                | 0
#  open_rv_24m                                | 0
#  max_bal_bc                                 | 13287
#  all_util                                   | 66
#  total_rev_hi_lim                           | 26700
#  inq_fi                                     | 2
#  total_cu_tl                                | 0
#  inq_last_12m                               | 1
#  acc_open_past_24mths                       | 4
#  avg_cur_bal                                | 14600
#  bc_open_to_buy                             | 11149
#  bc_util                                    | 58.2
#  chargeoff_within_12_mths                   | 0.0
#  delinq_amnt                                | 0
#  mo_sin_old_il_acct                         | 159.0
#  mo_sin_old_rev_tl_op                       | 214
#  mo_sin_rcnt_rev_tl_op                      | 81
#  mo_sin_rcnt_tl                             | 10
#  mort_acc                                   | 1
#  mths_since_recent_bc                       | 81
#  mths_since_recent_bc_dlq                   | null
#  mths_since_recent_inq                      | 5
#  mths_since_recent_revol_delinq             | null
#  num_accts_ever_120_pd                      | 0
#  num_actv_bc_tl                             | 3
#  num_actv_rev_tl                            | 3
#  num_bc_sats                                | 3
#  num_bc_tl                                  | 3
#  num_il_tl                                  | 8
#  num_op_rev_tl                              | 3
#  num_rev_accts                              | 4
#  num_rev_tl_bal_gt_0                        | 3
#  num_sats                                   | 9
#  num_tl_120dpd_2m                           | 0
#  num_tl_30dpd                               | 0
#  num_tl_90g_dpd_24m                         | 0
#  num_tl_op_past_12m                         | 1
#  pct_tl_nvr_dlq                             | 100.0
#  percent_bc_gt_75                           | 33.3
#  pub_rec_bankruptcies                       | 0
#  tax_liens                                  | 0
#  tot_hi_cred_lim                            | 176598
#  total_bal_ex_mort                          | 50920
#  total_bc_limit                             | 26700
#  total_il_high_credit_limit                 | 50898
#  revol_bal_joint                            | null
#  sec_app_earliest_cr_line                   | null
#  sec_app_inq_last_6mths                     | null
#  sec_app_mort_acc                           | null
#  sec_app_open_acc                           | null
#  sec_app_revol_util                         | null
#  sec_app_open_act_il                        | null
#  sec_app_num_rev_accts                      | null
#  sec_app_chargeoff_within_12_mths           | null
#  sec_app_collections_12_mths_ex_med         | null
#  sec_app_mths_since_last_major_derog        | null
#  hardship_flag                              | N
#  hardship_type                              | null
#  hardship_reason                            | null
#  hardship_status                            | null
#  deferral_term                              | null
#  hardship_amount                            | null
#  hardship_start_date                        | null
#  hardship_end_date                          | null
#  payment_plan_start_date                    | null
#  hardship_length                            | null
#  hardship_dpd                               | null
#  hardship_loan_status                       | null
#  orig_projected_additional_accrued_interest | null
#  hardship_payoff_balance_amount             | null
#  hardship_last_payment_amount               | null
#  disbursement_method                        | Cash
#  debt_settlement_flag                       | N
#  debt_settlement_flag_date                  | null
#  settlement_status                          | null
#  settlement_date                            | null
#  settlement_amount                          | null
#  settlement_percentage                      | null
#  settlement_term                            | null
# only showing top 20 rows

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lit

# Spark oturumu başlatma
spark = SparkSession.builder.appName("MissingValuesPercentage").getOrCreate()

# Eksik değer yüzdesini hesaplama ve sütunları seçme
threshold_percentage = 20  # %20'nin altındaki sütunları seçme eşik değeri
selected_columns = [c for c in df.columns if (df.filter(col(c).isNotNull()).count() / df.count()) * 100 >= threshold_percentage]

# Yeni DataFrame'i oluşturma
new_df = df.select(selected_columns)

# Sonuçları yazdırma
print("Total features before:", len(df.columns))
print("Total features now:", len(new_df.columns))
# Out:
# [Stage 2083:===============================>                       (8 + 6) / 14]
# Total features before: 145
# Total features now: 106

# %%
new_df.show(truncate=False, vertical=True)
# Out:
# -RECORD 0-----------------------------------------------------
#  loan_amnt                      | 2500
#  funded_amnt                    | 2500
#  funded_amnt_inv                | 2500.0
#  term                           |  36 months
#  int_rate                       | 13.56
#  installment                    | 84.92
#  grade                          | C
#  sub_grade                      | C1
#  emp_title                      | Chef
#  emp_length                     | 10+ years
#  home_ownership                 | RENT
#  annual_inc                     | 55000
#  verification_status            | Not Verified
#  issue_d                        | Dec-2018
#  loan_status                    | Current
#  pymnt_plan                     | n
#  purpose                        | debt_consolidation
#  title                          | Debt consolidation
#  zip_code                       | 109xx
#  addr_state                     | NY
#  dti                            | 18.24
#  delinq_2yrs                    | 0
#  earliest_cr_line               | Apr-2001
#  inq_last_6mths                 | 1
#  mths_since_last_delinq         | null
#  open_acc                       | 9
#  pub_rec                        | 1
#  revol_bal                      | 4341
#  revol_util                     | 10.3
#  total_acc                      | 34
#  initial_list_status            | w
#  out_prncp                      | 2386.02
#  out_prncp_inv                  | 2386.02
#  total_pymnt                    | 167.02
#  total_pymnt_inv                | 167.02
#  total_rec_prncp                | 113.98
#  total_rec_int                  | 53.04
#  total_rec_late_fee             | 0.0
#  recoveries                     | 0.0
#  collection_recovery_fee        | 0.0
#  last_pymnt_d                   | Feb-2019
#  last_pymnt_amnt                | 84.92
#  next_pymnt_d                   | Mar-2019
#  last_credit_pull_d             | Feb-2019
#  collections_12_mths_ex_med     | 0
#  mths_since_last_major_derog    | null
#  policy_code                    | 1
#  application_type               | Individual
#  acc_now_delinq                 | 0
#  tot_coll_amt                   | 0
#  tot_cur_bal                    | 16901
#  open_acc_6m                    | 2
#  open_act_il                    | 2
#  open_il_12m                    | 1
#  open_il_24m                    | 2
#  mths_since_rcnt_il             | 2
#  total_bal_il                   | 12560
#  il_util                        | 69
#  open_rv_12m                    | 2
#  open_rv_24m                    | 7
#  max_bal_bc                     | 2137
#  all_util                       | 28
#  total_rev_hi_lim               | 42000
#  inq_fi                         | 1
#  total_cu_tl                    | 11
#  inq_last_12m                   | 2
#  acc_open_past_24mths           | 9
#  avg_cur_bal                    | 1878
#  bc_open_to_buy                 | 34360
#  bc_util                        | 5.9
#  chargeoff_within_12_mths       | 0.0
#  delinq_amnt                    | 0
#  mo_sin_old_il_acct             | 140.0
#  mo_sin_old_rev_tl_op           | 212
#  mo_sin_rcnt_rev_tl_op          | 1
#  mo_sin_rcnt_tl                 | 1
#  mort_acc                       | 0
#  mths_since_recent_bc           | 1
#  mths_since_recent_bc_dlq       | null
#  mths_since_recent_inq          | 2
#  mths_since_recent_revol_delinq | null
#  num_accts_ever_120_pd          | 0
#  num_actv_bc_tl                 | 2
#  num_actv_rev_tl                | 5
#  num_bc_sats                    | 3
#  num_bc_tl                      | 3
#  num_il_tl                      | 16
#  num_op_rev_tl                  | 7
#  num_rev_accts                  | 18
#  num_rev_tl_bal_gt_0            | 5
#  num_sats                       | 9
#  num_tl_120dpd_2m               | 0
#  num_tl_30dpd                   | 0
#  num_tl_90g_dpd_24m             | 0
#  num_tl_op_past_12m             | 3
#  pct_tl_nvr_dlq                 | 100.0
#  percent_bc_gt_75               | 0.0
#  pub_rec_bankruptcies           | 1
#  tax_liens                      | 0
#  tot_hi_cred_lim                | 60124
#  total_bal_ex_mort              | 16901
#  total_bc_limit                 | 36500
#  total_il_high_credit_limit     | 18124
#  hardship_flag                  | N
#  disbursement_method            | Cash
#  debt_settlement_flag           | N
# -RECORD 1-----------------------------------------------------
#  loan_amnt                      | 30000
#  funded_amnt                    | 30000
#  funded_amnt_inv                | 30000.0
#  term                           |  60 months
#  int_rate                       | 18.94
#  installment                    | 777.23
#  grade                          | D
#  sub_grade                      | D2
#  emp_title                      | Postmaster
#  emp_length                     | 10+ years
#  home_ownership                 | MORTGAGE
#  annual_inc                     | 90000
#  verification_status            | Source Verified
#  issue_d                        | Dec-2018
#  loan_status                    | Current
#  pymnt_plan                     | n
#  purpose                        | debt_consolidation
#  title                          | Debt consolidation
#  zip_code                       | 713xx
#  addr_state                     | LA
#  dti                            | 26.52
#  delinq_2yrs                    | 0
#  earliest_cr_line               | Jun-1987
#  inq_last_6mths                 | 0
#  mths_since_last_delinq         | 71
#  open_acc                       | 13
#  pub_rec                        | 1
#  revol_bal                      | 12315
#  revol_util                     | 24.2
#  total_acc                      | 44
#  initial_list_status            | w
#  out_prncp                      | 29387.75
#  out_prncp_inv                  | 29387.75
#  total_pymnt                    | 1507.11
#  total_pymnt_inv                | 1507.11
#  total_rec_prncp                | 612.25
#  total_rec_int                  | 894.86
#  total_rec_late_fee             | 0.0
#  recoveries                     | 0.0
#  collection_recovery_fee        | 0.0
#  last_pymnt_d                   | Feb-2019
#  last_pymnt_amnt                | 777.23
#  next_pymnt_d                   | Mar-2019
#  last_credit_pull_d             | Feb-2019
#  collections_12_mths_ex_med     | 0
#  mths_since_last_major_derog    | null
#  policy_code                    | 1
#  application_type               | Individual
#  acc_now_delinq                 | 0
#  tot_coll_amt                   | 1208
#  tot_cur_bal                    | 321915
#  open_acc_6m                    | 4
#  open_act_il                    | 4
#  open_il_12m                    | 2
#  open_il_24m                    | 3
#  mths_since_rcnt_il             | 3
#  total_bal_il                   | 87153
#  il_util                        | 88
#  open_rv_12m                    | 4
#  open_rv_24m                    | 5
#  max_bal_bc                     | 998
#  all_util                       | 57
#  total_rev_hi_lim               | 50800
#  inq_fi                         | 2
#  total_cu_tl                    | 15
#  inq_last_12m                   | 2
#  acc_open_past_24mths           | 10
#  avg_cur_bal                    | 24763
#  bc_open_to_buy                 | 13761
#  bc_util                        | 8.3
#  chargeoff_within_12_mths       | 0.0
#  delinq_amnt                    | 0
#  mo_sin_old_il_acct             | 163.0
#  mo_sin_old_rev_tl_op           | 378
#  mo_sin_rcnt_rev_tl_op          | 4
#  mo_sin_rcnt_tl                 | 3
#  mort_acc                       | 3
#  mths_since_recent_bc           | 4
#  mths_since_recent_bc_dlq       | null
#  mths_since_recent_inq          | 4
#  mths_since_recent_revol_delinq | null
#  num_accts_ever_120_pd          | 0
#  num_actv_bc_tl                 | 2
#  num_actv_rev_tl                | 4
#  num_bc_sats                    | 4
#  num_bc_tl                      | 9
#  num_il_tl                      | 27
#  num_op_rev_tl                  | 8
#  num_rev_accts                  | 14
#  num_rev_tl_bal_gt_0            | 4
#  num_sats                       | 13
#  num_tl_120dpd_2m               | 0
#  num_tl_30dpd                   | 0
#  num_tl_90g_dpd_24m             | 0
#  num_tl_op_past_12m             | 6
#  pct_tl_nvr_dlq                 | 95.0
#  percent_bc_gt_75               | 0.0
#  pub_rec_bankruptcies           | 1
#  tax_liens                      | 0
#  tot_hi_cred_lim                | 372872
#  total_bal_ex_mort              | 99468
#  total_bc_limit                 | 15000
#  total_il_high_credit_limit     | 94072
#  hardship_flag                  | N
#  disbursement_method            | Cash
#  debt_settlement_flag           | N
# -RECORD 2-----------------------------------------------------
#  loan_amnt                      | 5000
#  funded_amnt                    | 5000
#  funded_amnt_inv                | 5000.0
#  term                           |  36 months
#  int_rate                       | 17.97
#  installment                    | 180.69
#  grade                          | D
#  sub_grade                      | D1
#  emp_title                      | Administrative
#  emp_length                     | 6 years
#  home_ownership                 | MORTGAGE
#  annual_inc                     | 59280
#  verification_status            | Source Verified
#  issue_d                        | Dec-2018
#  loan_status                    | Current
#  pymnt_plan                     | n
#  purpose                        | debt_consolidation
#  title                          | Debt consolidation
#  zip_code                       | 490xx
#  addr_state                     | MI
#  dti                            | 10.51
#  delinq_2yrs                    | 0
#  earliest_cr_line               | Apr-2011
#  inq_last_6mths                 | 0
#  mths_since_last_delinq         | null
#  open_acc                       | 8
#  pub_rec                        | 0
#  revol_bal                      | 4599
#  revol_util                     | 19.1
#  total_acc                      | 13
#  initial_list_status            | w
#  out_prncp                      | 4787.21
#  out_prncp_inv                  | 4787.21
#  total_pymnt                    | 353.89
#  total_pymnt_inv                | 353.89
#  total_rec_prncp                | 212.79
#  total_rec_int                  | 141.10
#  total_rec_late_fee             | 0.0
#  recoveries                     | 0.0
#  collection_recovery_fee        | 0.0
#  last_pymnt_d                   | Feb-2019
#  last_pymnt_amnt                | 180.69
#  next_pymnt_d                   | Mar-2019
#  last_credit_pull_d             | Feb-2019
#  collections_12_mths_ex_med     | 0
#  mths_since_last_major_derog    | null
#  policy_code                    | 1
#  application_type               | Individual
#  acc_now_delinq                 | 0
#  tot_coll_amt                   | 0
#  tot_cur_bal                    | 110299
#  open_acc_6m                    | 0
#  open_act_il                    | 1
#  open_il_12m                    | 0
#  open_il_24m                    | 2
#  mths_since_rcnt_il             | 14
#  total_bal_il                   | 7150
#  il_util                        | 72
#  open_rv_12m                    | 0
#  open_rv_24m                    | 2
#  max_bal_bc                     | 0
#  all_util                       | 35
#  total_rev_hi_lim               | 24100
#  inq_fi                         | 1
#  total_cu_tl                    | 5
#  inq_last_12m                   | 0
#  acc_open_past_24mths           | 4
#  avg_cur_bal                    | 18383
#  bc_open_to_buy                 | 13800
#  bc_util                        | 0
#  chargeoff_within_12_mths       | 0.0
#  delinq_amnt                    | 0
#  mo_sin_old_il_acct             | 87.0
#  mo_sin_old_rev_tl_op           | 92
#  mo_sin_rcnt_rev_tl_op          | 15
#  mo_sin_rcnt_tl                 | 14
#  mort_acc                       | 2
#  mths_since_recent_bc           | 77
#  mths_since_recent_bc_dlq       | null
#  mths_since_recent_inq          | 14
#  mths_since_recent_revol_delinq | null
#  num_accts_ever_120_pd          | 0
#  num_actv_bc_tl                 | 0
#  num_actv_rev_tl                | 3
#  num_bc_sats                    | 3
#  num_bc_tl                      | 3
#  num_il_tl                      | 4
#  num_op_rev_tl                  | 6
#  num_rev_accts                  | 7
#  num_rev_tl_bal_gt_0            | 3
#  num_sats                       | 8
#  num_tl_120dpd_2m               | 0
#  num_tl_30dpd                   | 0
#  num_tl_90g_dpd_24m             | 0
#  num_tl_op_past_12m             | 0
#  pct_tl_nvr_dlq                 | 100.0
#  percent_bc_gt_75               | 0.0
#  pub_rec_bankruptcies           | 0
#  tax_liens                      | 0
#  tot_hi_cred_lim                | 136927
#  total_bal_ex_mort              | 11749
#  total_bc_limit                 | 13800
#  total_il_high_credit_limit     | 10000
#  hardship_flag                  | N
#  disbursement_method            | Cash
#  debt_settlement_flag           | N
# -RECORD 3-----------------------------------------------------
#  loan_amnt                      | 4000
#  funded_amnt                    | 4000
#  funded_amnt_inv                | 4000.0
#  term                           |  36 months
#  int_rate                       | 18.94
#  installment                    | 146.51
#  grade                          | D
#  sub_grade                      | D2
#  emp_title                      | IT Supervisor
#  emp_length                     | 10+ years
#  home_ownership                 | MORTGAGE
#  annual_inc                     | 92000
#  verification_status            | Source Verified
#  issue_d                        | Dec-2018
#  loan_status                    | Current
#  pymnt_plan                     | n
#  purpose                        | debt_consolidation
#  title                          | Debt consolidation
#  zip_code                       | 985xx
#  addr_state                     | WA
#  dti                            | 16.74
#  delinq_2yrs                    | 0
#  earliest_cr_line               | Feb-2006
#  inq_last_6mths                 | 0
#  mths_since_last_delinq         | null
#  open_acc                       | 10
#  pub_rec                        | 0
#  revol_bal                      | 5468
#  revol_util                     | 78.1
#  total_acc                      | 13
#  initial_list_status            | w
#  out_prncp                      | 3831.93
#  out_prncp_inv                  | 3831.93
#  total_pymnt                    | 286.71
#  total_pymnt_inv                | 286.71
#  total_rec_prncp                | 168.07
#  total_rec_int                  | 118.64
#  total_rec_late_fee             | 0.0
#  recoveries                     | 0.0
#  collection_recovery_fee        | 0.0
#  last_pymnt_d                   | Feb-2019
#  last_pymnt_amnt                | 146.51
#  next_pymnt_d                   | Mar-2019
#  last_credit_pull_d             | Feb-2019
#  collections_12_mths_ex_med     | 0
#  mths_since_last_major_derog    | null
#  policy_code                    | 1
#  application_type               | Individual
#  acc_now_delinq                 | 0
#  tot_coll_amt                   | 686
#  tot_cur_bal                    | 305049
#  open_acc_6m                    | 1
#  open_act_il                    | 5
#  open_il_12m                    | 3
#  open_il_24m                    | 5
#  mths_since_rcnt_il             | 5
#  total_bal_il                   | 30683
#  il_util                        | 68
#  open_rv_12m                    | 0
#  open_rv_24m                    | 0
#  max_bal_bc                     | 3761
#  all_util                       | 70
#  total_rev_hi_lim               | 7000
#  inq_fi                         | 2
#  total_cu_tl                    | 4
#  inq_last_12m                   | 3
#  acc_open_past_24mths           | 5
#  avg_cur_bal                    | 30505
#  bc_open_to_buy                 | 1239
#  bc_util                        | 75.2
#  chargeoff_within_12_mths       | 0.0
#  delinq_amnt                    | 0
#  mo_sin_old_il_acct             | 62.0
#  mo_sin_old_rev_tl_op           | 154
#  mo_sin_rcnt_rev_tl_op          | 64
#  mo_sin_rcnt_tl                 | 5
#  mort_acc                       | 3
#  mths_since_recent_bc           | 64
#  mths_since_recent_bc_dlq       | null
#  mths_since_recent_inq          | 5
#  mths_since_recent_revol_delinq | null
#  num_accts_ever_120_pd          | 0
#  num_actv_bc_tl                 | 1
#  num_actv_rev_tl                | 2
#  num_bc_sats                    | 1
#  num_bc_tl                      | 2
#  num_il_tl                      | 7
#  num_op_rev_tl                  | 2
#  num_rev_accts                  | 3
#  num_rev_tl_bal_gt_0            | 2
#  num_sats                       | 10
#  num_tl_120dpd_2m               | 0
#  num_tl_30dpd                   | 0
#  num_tl_90g_dpd_24m             | 0
#  num_tl_op_past_12m             | 3
#  pct_tl_nvr_dlq                 | 100.0
#  percent_bc_gt_75               | 100.0
#  pub_rec_bankruptcies           | 0
#  tax_liens                      | 0
#  tot_hi_cred_lim                | 385183
#  total_bal_ex_mort              | 36151
#  total_bc_limit                 | 5000
#  total_il_high_credit_limit     | 44984
#  hardship_flag                  | N
#  disbursement_method            | Cash
#  debt_settlement_flag           | N
# -RECORD 4-----------------------------------------------------
#  loan_amnt                      | 30000
#  funded_amnt                    | 30000
#  funded_amnt_inv                | 30000.0
#  term                           |  60 months
#  int_rate                       | 16.14
#  installment                    | 731.78
#  grade                          | C
#  sub_grade                      | C4
#  emp_title                      | Mechanic
#  emp_length                     | 10+ years
#  home_ownership                 | MORTGAGE
#  annual_inc                     | 57250
#  verification_status            | Not Verified
#  issue_d                        | Dec-2018
#  loan_status                    | Current
#  pymnt_plan                     | n
#  purpose                        | debt_consolidation
#  title                          | Debt consolidation
#  zip_code                       | 212xx
#  addr_state                     | MD
#  dti                            | 26.35
#  delinq_2yrs                    | 0
#  earliest_cr_line               | Dec-2000
#  inq_last_6mths                 | 0
#  mths_since_last_delinq         | null
#  open_acc                       | 12
#  pub_rec                        | 0
#  revol_bal                      | 829
#  revol_util                     | 3.6
#  total_acc                      | 26
#  initial_list_status            | w
#  out_prncp                      | 29339.02
#  out_prncp_inv                  | 29339.02
#  total_pymnt                    | 1423.21
#  total_pymnt_inv                | 1423.21
#  total_rec_prncp                | 660.98
#  total_rec_int                  | 762.23
#  total_rec_late_fee             | 0.0
#  recoveries                     | 0.0
#  collection_recovery_fee        | 0.0
#  last_pymnt_d                   | Feb-2019
#  last_pymnt_amnt                | 731.78
#  next_pymnt_d                   | Mar-2019
#  last_credit_pull_d             | Feb-2019
#  collections_12_mths_ex_med     | 0
#  mths_since_last_major_derog    | null
#  policy_code                    | 1
#  application_type               | Individual
#  acc_now_delinq                 | 0
#  tot_coll_amt                   | 0
#  tot_cur_bal                    | 116007
#  open_acc_6m                    | 3
#  open_act_il                    | 5
#  open_il_12m                    | 3
#  open_il_24m                    | 5
#  mths_since_rcnt_il             | 4
#  total_bal_il                   | 28845
#  il_util                        | 89
#  open_rv_12m                    | 2
#  open_rv_24m                    | 4
#  max_bal_bc                     | 516
#  all_util                       | 54
#  total_rev_hi_lim               | 23100
#  inq_fi                         | 1
#  total_cu_tl                    | 0
#  inq_last_12m                   | 0
#  acc_open_past_24mths           | 9
#  avg_cur_bal                    | 9667
#  bc_open_to_buy                 | 8471
#  bc_util                        | 8.9
#  chargeoff_within_12_mths       | 0.0
#  delinq_amnt                    | 0
#  mo_sin_old_il_acct             | 53.0
#  mo_sin_old_rev_tl_op           | 216
#  mo_sin_rcnt_rev_tl_op          | 2
#  mo_sin_rcnt_tl                 | 2
#  mort_acc                       | 2
#  mths_since_recent_bc           | 2
#  mths_since_recent_bc_dlq       | null
#  mths_since_recent_inq          | 13
#  mths_since_recent_revol_delinq | null
#  num_accts_ever_120_pd          | 0
#  num_actv_bc_tl                 | 2
#  num_actv_rev_tl                | 2
#  num_bc_sats                    | 3
#  num_bc_tl                      | 8
#  num_il_tl                      | 9
#  num_op_rev_tl                  | 6
#  num_rev_accts                  | 15
#  num_rev_tl_bal_gt_0            | 2
#  num_sats                       | 12
#  num_tl_120dpd_2m               | 0
#  num_tl_30dpd                   | 0
#  num_tl_90g_dpd_24m             | 0
#  num_tl_op_past_12m             | 5
#  pct_tl_nvr_dlq                 | 92.3
#  percent_bc_gt_75               | 0.0
#  pub_rec_bankruptcies           | 0
#  tax_liens                      | 0
#  tot_hi_cred_lim                | 157548
#  total_bal_ex_mort              | 29674
#  total_bc_limit                 | 9300
#  total_il_high_credit_limit     | 32332
#  hardship_flag                  | N
#  disbursement_method            | Cash
#  debt_settlement_flag           | N
# -RECORD 5-----------------------------------------------------
#  loan_amnt                      | 5550
#  funded_amnt                    | 5550
#  funded_amnt_inv                | 5550.0
#  term                           |  36 months
#  int_rate                       | 15.02
#  installment                    | 192.45
#  grade                          | C
#  sub_grade                      | C3
#  emp_title                      | Director COE
#  emp_length                     | 10+ years
#  home_ownership                 | MORTGAGE
#  annual_inc                     | 152500
#  verification_status            | Not Verified
#  issue_d                        | Dec-2018
#  loan_status                    | Current
#  pymnt_plan                     | n
#  purpose                        | credit_card
#  title                          | Credit card refinancing
#  zip_code                       | 461xx
#  addr_state                     | IN
#  dti                            | 37.94
#  delinq_2yrs                    | 0
#  earliest_cr_line               | Sep-2002
#  inq_last_6mths                 | 3
#  mths_since_last_delinq         | null
#  open_acc                       | 18
#  pub_rec                        | 0
#  revol_bal                      | 53854
#  revol_util                     | 48.1
#  total_acc                      | 44
#  initial_list_status            | w
#  out_prncp                      | 5302.50
#  out_prncp_inv                  | 5302.50
#  total_pymnt                    | 377.95
#  total_pymnt_inv                | 377.95
#  total_rec_prncp                | 247.50
#  total_rec_int                  | 130.45
#  total_rec_late_fee             | 0.0
#  recoveries                     | 0.0
#  collection_recovery_fee        | 0.0
#  last_pymnt_d                   | Feb-2019
#  last_pymnt_amnt                | 192.45
#  next_pymnt_d                   | Mar-2019
#  last_credit_pull_d             | Feb-2019
#  collections_12_mths_ex_med     | 0
#  mths_since_last_major_derog    | null
#  policy_code                    | 1
#  application_type               | Individual
#  acc_now_delinq                 | 0
#  tot_coll_amt                   | 0
#  tot_cur_bal                    | 685749
#  open_acc_6m                    | 1
#  open_act_il                    | 7
#  open_il_12m                    | 2
#  open_il_24m                    | 3
#  mths_since_rcnt_il             | 4
#  total_bal_il                   | 131524
#  il_util                        | 72
#  open_rv_12m                    | 1
#  open_rv_24m                    | 4
#  max_bal_bc                     | 17584
#  all_util                       | 58
#  total_rev_hi_lim               | 111900
#  inq_fi                         | 2
#  total_cu_tl                    | 4
#  inq_last_12m                   | 6
#  acc_open_past_24mths           | 8
#  avg_cur_bal                    | 40338
#  bc_open_to_buy                 | 23746
#  bc_util                        | 64
#  chargeoff_within_12_mths       | 0.0
#  delinq_amnt                    | 0
#  mo_sin_old_il_acct             | 195.0
#  mo_sin_old_rev_tl_op           | 176
#  mo_sin_rcnt_rev_tl_op          | 10
#  mo_sin_rcnt_tl                 | 4
#  mort_acc                       | 6
#  mths_since_recent_bc           | 20
#  mths_since_recent_bc_dlq       | null
#  mths_since_recent_inq          | 3
#  mths_since_recent_revol_delinq | null
#  num_accts_ever_120_pd          | 0
#  num_actv_bc_tl                 | 4
#  num_actv_rev_tl                | 6
#  num_bc_sats                    | 6
#  num_bc_tl                      | 10
#  num_il_tl                      | 23
#  num_op_rev_tl                  | 9
#  num_rev_accts                  | 15
#  num_rev_tl_bal_gt_0            | 7
#  num_sats                       | 18
#  num_tl_120dpd_2m               | 0
#  num_tl_30dpd                   | 0
#  num_tl_90g_dpd_24m             | 0
#  num_tl_op_past_12m             | 4
#  pct_tl_nvr_dlq                 | 100.0
#  percent_bc_gt_75               | 60.0
#  pub_rec_bankruptcies           | 0
#  tax_liens                      | 0
#  tot_hi_cred_lim                | 831687
#  total_bal_ex_mort              | 185378
#  total_bc_limit                 | 65900
#  total_il_high_credit_limit     | 203159
#  hardship_flag                  | N
#  disbursement_method            | Cash
#  debt_settlement_flag           | N
# -RECORD 6-----------------------------------------------------
#  loan_amnt                      | 2000
#  funded_amnt                    | 2000
#  funded_amnt_inv                | 2000.0
#  term                           |  36 months
#  int_rate                       | 17.97
#  installment                    | 72.28
#  grade                          | D
#  sub_grade                      | D1
#  emp_title                      | Account Manager
#  emp_length                     | 4 years
#  home_ownership                 | RENT
#  annual_inc                     | 51000
#  verification_status            | Source Verified
#  issue_d                        | Dec-2018
#  loan_status                    | Current
#  pymnt_plan                     | n
#  purpose                        | debt_consolidation
#  title                          | Debt consolidation
#  zip_code                       | 606xx
#  addr_state                     | IL
#  dti                            | 2.4
#  delinq_2yrs                    | 0
#  earliest_cr_line               | Nov-2004
#  inq_last_6mths                 | 1
#  mths_since_last_delinq         | null
#  open_acc                       | 1
#  pub_rec                        | 0
#  revol_bal                      | 0
#  revol_util                     | null
#  total_acc                      | 9
#  initial_list_status            | w
#  out_prncp                      | 1914.71
#  out_prncp_inv                  | 1914.71
#  total_pymnt                    | 141.56
#  total_pymnt_inv                | 141.56
#  total_rec_prncp                | 85.29
#  total_rec_int                  | 56.27
#  total_rec_late_fee             | 0.0
#  recoveries                     | 0.0
#  collection_recovery_fee        | 0.0
#  last_pymnt_d                   | Feb-2019
#  last_pymnt_amnt                | 72.28
#  next_pymnt_d                   | Mar-2019
#  last_credit_pull_d             | Feb-2019
#  collections_12_mths_ex_med     | 0
#  mths_since_last_major_derog    | null
#  policy_code                    | 1
#  application_type               | Individual
#  acc_now_delinq                 | 0
#  tot_coll_amt                   | 0
#  tot_cur_bal                    | 854
#  open_acc_6m                    | 0
#  open_act_il                    | 0
#  open_il_12m                    | 2
#  open_il_24m                    | 3
#  mths_since_rcnt_il             | 7
#  total_bal_il                   | 0
#  il_util                        | null
#  open_rv_12m                    | 0
#  open_rv_24m                    | 1
#  max_bal_bc                     | 0
#  all_util                       | 100
#  total_rev_hi_lim               | 0
#  inq_fi                         | 0
#  total_cu_tl                    | 0
#  inq_last_12m                   | 1
#  acc_open_past_24mths           | 4
#  avg_cur_bal                    | 854
#  bc_open_to_buy                 | null
#  bc_util                        | null
#  chargeoff_within_12_mths       | 0.0
#  delinq_amnt                    | 0
#  mo_sin_old_il_acct             | 169.0
#  mo_sin_old_rev_tl_op           | 40
#  mo_sin_rcnt_rev_tl_op          | 23
#  mo_sin_rcnt_tl                 | 7
#  mort_acc                       | 0
#  mths_since_recent_bc           | null
#  mths_since_recent_bc_dlq       | null
#  mths_since_recent_inq          | 1
#  mths_since_recent_revol_delinq | null
#  num_accts_ever_120_pd          | 0
#  num_actv_bc_tl                 | 0
#  num_actv_rev_tl                | 0
#  num_bc_sats                    | 0
#  num_bc_tl                      | 3
#  num_il_tl                      | 5
#  num_op_rev_tl                  | 0
#  num_rev_accts                  | 3
#  num_rev_tl_bal_gt_0            | 0
#  num_sats                       | 1
#  num_tl_120dpd_2m               | 0
#  num_tl_30dpd                   | 0
#  num_tl_90g_dpd_24m             | 0
#  num_tl_op_past_12m             | 2
#  pct_tl_nvr_dlq                 | 100.0
#  percent_bc_gt_75               | null
#  pub_rec_bankruptcies           | 0
#  tax_liens                      | 0
#  tot_hi_cred_lim                | 854
#  total_bal_ex_mort              | 854
#  total_bc_limit                 | 0
#  total_il_high_credit_limit     | 0
#  hardship_flag                  | N
#  disbursement_method            | Cash
#  debt_settlement_flag           | N
# -RECORD 7-----------------------------------------------------
#  loan_amnt                      | 6000
#  funded_amnt                    | 6000
#  funded_amnt_inv                | 6000.0
#  term                           |  36 months
#  int_rate                       | 13.56
#  installment                    | 203.79
#  grade                          | C
#  sub_grade                      | C1
#  emp_title                      | Assistant Director
#  emp_length                     | 10+ years
#  home_ownership                 | RENT
# ...
#  avg_cur_bal                    | 19915
#  bc_open_to_buy                 | 0
#  bc_util                        | 104.4
#  chargeoff_within_12_mths       | 0.0
#  delinq_amnt                    | 0
#  mo_sin_old_il_acct             | 90.0
#  mo_sin_old_rev_tl_op           | 98
#  mo_sin_rcnt_rev_tl_op          | 27
#  mo_sin_rcnt_tl                 | 27
#  mort_acc                       | 2
#  mths_since_recent_bc           | 84
#  mths_since_recent_bc_dlq       | null
#  mths_since_recent_inq          | null
#  mths_since_recent_revol_delinq | null
#  num_accts_ever_120_pd          | 0
#  num_actv_bc_tl                 | 1
#  num_actv_rev_tl                | 3
#  num_bc_sats                    | 1
#  num_bc_tl                      | 1
#  num_il_tl                      | 2
#  num_op_rev_tl                  | 3
#  num_rev_accts                  | 4
#  num_rev_tl_bal_gt_0            | 3
#  num_sats                       | 4
#  num_tl_120dpd_2m               | 0
#  num_tl_30dpd                   | 0
#  num_tl_90g_dpd_24m             | 0
#  num_tl_op_past_12m             | 0
#  pct_tl_nvr_dlq                 | 100.0
#  percent_bc_gt_75               | 100.0
#  pub_rec_bankruptcies           | 0
#  tax_liens                      | 0
#  tot_hi_cred_lim                | 92334
#  total_bal_ex_mort              | 3044
#  total_bc_limit                 | 1000
#  total_il_high_credit_limit     | 0
#  hardship_flag                  | N
#  disbursement_method            | Cash
#  debt_settlement_flag           | N
# -RECORD 18----------------------------------------------------
#  loan_amnt                      | 16000
#  funded_amnt                    | 16000
#  funded_amnt_inv                | 16000.0
#  term                           |  60 months
#  int_rate                       | 20.89
#  installment                    | 431.87
#  grade                          | D
#  sub_grade                      | D4
#  emp_title                      | Neonatal Nurse Practitioner
#  emp_length                     | 4 years
#  home_ownership                 | MORTGAGE
#  annual_inc                     | 120000
#  verification_status            | Not Verified
#  issue_d                        | Dec-2018
#  loan_status                    | Current
#  pymnt_plan                     | n
#  purpose                        | credit_card
#  title                          | Credit card refinancing
#  zip_code                       | 720xx
#  addr_state                     | AR
#  dti                            | 27.57
#  delinq_2yrs                    | 1
#  earliest_cr_line               | Jul-2005
#  inq_last_6mths                 | 0
#  mths_since_last_delinq         | 8
#  open_acc                       | 13
#  pub_rec                        | 0
#  revol_bal                      | 18826
#  revol_util                     | 82.2
#  total_acc                      | 37
#  initial_list_status            | w
#  out_prncp                      | 15690.66
#  out_prncp_inv                  | 15690.66
#  total_pymnt                    | 835.89
#  total_pymnt_inv                | 835.89
#  total_rec_prncp                | 309.34
#  total_rec_int                  | 526.55
#  total_rec_late_fee             | 0.0
#  recoveries                     | 0.0
#  collection_recovery_fee        | 0.0
#  last_pymnt_d                   | Feb-2019
#  last_pymnt_amnt                | 431.87
#  next_pymnt_d                   | Mar-2019
#  last_credit_pull_d             | Feb-2019
#  collections_12_mths_ex_med     | 0
#  mths_since_last_major_derog    | 35
#  policy_code                    | 1
#  application_type               | Individual
#  acc_now_delinq                 | 0
#  tot_coll_amt                   | 0
#  tot_cur_bal                    | 434239
#  open_acc_6m                    | 1
#  open_act_il                    | 6
#  open_il_12m                    | 1
#  open_il_24m                    | 4
#  mths_since_rcnt_il             | 4
#  total_bal_il                   | 247928
#  il_util                        | 90
#  open_rv_12m                    | 1
#  open_rv_24m                    | 1
#  max_bal_bc                     | 9439
#  all_util                       | 87
#  total_rev_hi_lim               | 22900
#  inq_fi                         | 6
#  total_cu_tl                    | 1
#  inq_last_12m                   | 2
#  acc_open_past_24mths           | 5
#  avg_cur_bal                    | 33403
#  bc_open_to_buy                 | 430
#  bc_util                        | 96.8
#  chargeoff_within_12_mths       | 0.0
#  delinq_amnt                    | 0
#  mo_sin_old_il_acct             | 136.0
#  mo_sin_old_rev_tl_op           | 146
#  mo_sin_rcnt_rev_tl_op          | 12
#  mo_sin_rcnt_tl                 | 4
#  mort_acc                       | 2
#  mths_since_recent_bc           | 12
#  mths_since_recent_bc_dlq       | 48
#  mths_since_recent_inq          | 4
#  mths_since_recent_revol_delinq | 8
#  num_accts_ever_120_pd          | 2
#  num_actv_bc_tl                 | 2
#  num_actv_rev_tl                | 4
#  num_bc_sats                    | 2
#  num_bc_tl                      | 5
#  num_il_tl                      | 24
#  num_op_rev_tl                  | 6
#  num_rev_accts                  | 10
#  num_rev_tl_bal_gt_0            | 4
#  num_sats                       | 13
#  num_tl_120dpd_2m               | 0
#  num_tl_30dpd                   | 0
#  num_tl_90g_dpd_24m             | 0
#  num_tl_op_past_12m             | 2
#  pct_tl_nvr_dlq                 | 86.5
#  percent_bc_gt_75               | 100.0
#  pub_rec_bankruptcies           | 0
#  tax_liens                      | 0
#  tot_hi_cred_lim                | 444217
#  total_bal_ex_mort              | 266754
#  total_bc_limit                 | 13500
#  total_il_high_credit_limit     | 239338
#  hardship_flag                  | N
#  disbursement_method            | Cash
#  debt_settlement_flag           | N
# -RECORD 19----------------------------------------------------
#  loan_amnt                      | 13000
#  funded_amnt                    | 13000
#  funded_amnt_inv                | 13000.0
#  term                           |  60 months
#  int_rate                       | 14.47
#  installment                    | 305.67
#  grade                          | C
#  sub_grade                      | C2
#  emp_title                      | Stationary Engineer
#  emp_length                     | 10+ years
#  home_ownership                 | MORTGAGE
#  annual_inc                     | 75000
#  verification_status            | Not Verified
#  issue_d                        | Dec-2018
#  loan_status                    | Current
#  pymnt_plan                     | n
#  purpose                        | debt_consolidation
#  title                          | Debt consolidation
#  zip_code                       | 741xx
#  addr_state                     | OK
#  dti                            | 26.16
#  delinq_2yrs                    | 0
#  earliest_cr_line               | Feb-2001
#  inq_last_6mths                 | 1
#  mths_since_last_delinq         | null
#  open_acc                       | 9
#  pub_rec                        | 0
#  revol_bal                      | 15551
#  revol_util                     | 58.2
#  total_acc                      | 13
#  initial_list_status            | w
#  out_prncp                      | 12700.38
#  out_prncp_inv                  | 12700.38
#  total_pymnt                    | 595.66
#  total_pymnt_inv                | 595.66
#  total_rec_prncp                | 299.62
#  total_rec_int                  | 296.04
#  total_rec_late_fee             | 0.0
#  recoveries                     | 0.0
#  collection_recovery_fee        | 0.0
#  last_pymnt_d                   | Feb-2019
#  last_pymnt_amnt                | 305.67
#  next_pymnt_d                   | Mar-2019
#  last_credit_pull_d             | Feb-2019
#  collections_12_mths_ex_med     | 0
#  mths_since_last_major_derog    | null
#  policy_code                    | 1
#  application_type               | Individual
#  acc_now_delinq                 | 0
#  tot_coll_amt                   | 0
#  tot_cur_bal                    | 131400
#  open_acc_6m                    | 0
#  open_act_il                    | 5
#  open_il_12m                    | 1
#  open_il_24m                    | 4
#  mths_since_rcnt_il             | 10
#  total_bal_il                   | 35369
#  il_util                        | 70
#  open_rv_12m                    | 0
#  open_rv_24m                    | 0
#  max_bal_bc                     | 13287
#  all_util                       | 66
#  total_rev_hi_lim               | 26700
#  inq_fi                         | 2
#  total_cu_tl                    | 0
#  inq_last_12m                   | 1
#  acc_open_past_24mths           | 4
#  avg_cur_bal                    | 14600
#  bc_open_to_buy                 | 11149
#  bc_util                        | 58.2
#  chargeoff_within_12_mths       | 0.0
#  delinq_amnt                    | 0
#  mo_sin_old_il_acct             | 159.0
#  mo_sin_old_rev_tl_op           | 214
#  mo_sin_rcnt_rev_tl_op          | 81
#  mo_sin_rcnt_tl                 | 10
#  mort_acc                       | 1
#  mths_since_recent_bc           | 81
#  mths_since_recent_bc_dlq       | null
#  mths_since_recent_inq          | 5
#  mths_since_recent_revol_delinq | null
#  num_accts_ever_120_pd          | 0
#  num_actv_bc_tl                 | 3
#  num_actv_rev_tl                | 3
#  num_bc_sats                    | 3
#  num_bc_tl                      | 3
#  num_il_tl                      | 8
#  num_op_rev_tl                  | 3
#  num_rev_accts                  | 4
#  num_rev_tl_bal_gt_0            | 3
#  num_sats                       | 9
#  num_tl_120dpd_2m               | 0
#  num_tl_30dpd                   | 0
#  num_tl_90g_dpd_24m             | 0
#  num_tl_op_past_12m             | 1
#  pct_tl_nvr_dlq                 | 100.0
#  percent_bc_gt_75               | 33.3
#  pub_rec_bankruptcies           | 0
#  tax_liens                      | 0
#  tot_hi_cred_lim                | 176598
#  total_bal_ex_mort              | 50920
#  total_bc_limit                 | 26700
#  total_il_high_credit_limit     | 50898
#  hardship_flag                  | N
#  disbursement_method            | Cash
#  debt_settlement_flag           | N
# only showing top 20 rows

# %%
# Spark oturumu başlatma
spark = SparkSession.builder.appName("SelectFeatures").getOrCreate()

# Seçilen sütunları belirleme
selected_features = ['term', 'int_rate', 'installment', 'loan_status']

# Sadece seçilen sütunları içeren yeni bir Spark DataFrame oluşturma
df_selected = new_df.select(selected_features)

# Seçilen sütunların sayısını yazdırma
print("Number of selected features:", len(selected_features))
# Out:
# Number of selected features: 4

# %%
# Sonuçları gösterme
df_selected.show()
# Out:
# +----------+--------+-----------+-----------+
# |      term|int_rate|installment|loan_status|
# +----------+--------+-----------+-----------+
# | 36 months|   13.56|      84.92|    Current|
# | 60 months|   18.94|     777.23|    Current|
# | 36 months|   17.97|     180.69|    Current|
# | 36 months|   18.94|     146.51|    Current|
# | 60 months|   16.14|     731.78|    Current|
# | 36 months|   15.02|     192.45|    Current|
# | 36 months|   17.97|      72.28|    Current|
# | 36 months|   13.56|     203.79|    Current|
# | 36 months|   17.97|     180.69|    Current|
# | 36 months|   14.47|     206.44|    Current|
# | 36 months|   22.35|     211.05|    Current|
# | 60 months|   11.31|     613.13|    Current|
# | 36 months|    8.19|     351.95|    Current|
# | 36 months|   17.97|      234.9|    Current|
# | 60 months|   12.98|     500.35|    Current|
# | 36 months|   16.14|      123.3|    Current|
# | 36 months|   12.98|      235.8|    Current|
# | 60 months|   16.91|     620.11|    Current|
# | 60 months|   20.89|     431.87|    Current|
# | 60 months|   14.47|     305.67|    Current|
# +----------+--------+-----------+-----------+
# only showing top 20 rows

# %%
from pyspark.sql import SparkSession

# Spark oturumu başlatma
spark = SparkSession.builder.appName("DropNullRows").getOrCreate()


# NaN içeren satırları silme
df = df_selected.na.drop()

# Sonuçları gösterme
df.show()
# Out:
# +----------+--------+-----------+-----------+
# |      term|int_rate|installment|loan_status|
# +----------+--------+-----------+-----------+
# | 36 months|   13.56|      84.92|    Current|
# | 60 months|   18.94|     777.23|    Current|
# | 36 months|   17.97|     180.69|    Current|
# | 36 months|   18.94|     146.51|    Current|
# | 60 months|   16.14|     731.78|    Current|
# | 36 months|   15.02|     192.45|    Current|
# | 36 months|   17.97|      72.28|    Current|
# | 36 months|   13.56|     203.79|    Current|
# | 36 months|   17.97|     180.69|    Current|
# | 36 months|   14.47|     206.44|    Current|
# | 36 months|   22.35|     211.05|    Current|
# | 60 months|   11.31|     613.13|    Current|
# | 36 months|    8.19|     351.95|    Current|
# | 36 months|   17.97|      234.9|    Current|
# | 60 months|   12.98|     500.35|    Current|
# | 36 months|   16.14|      123.3|    Current|
# | 36 months|   12.98|      235.8|    Current|
# | 60 months|   16.91|     620.11|    Current|
# | 60 months|   20.89|     431.87|    Current|
# | 60 months|   14.47|     305.67|    Current|
# +----------+--------+-----------+-----------+
# only showing top 20 rows

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import trim, regexp_replace
from pyspark.sql.types import IntegerType

# Spark oturumu başlatma
spark = SparkSession.builder.appName("TermColumnTransformation").getOrCreate()


# Term sütununu dönüştürme
df = df.withColumn("term", trim(regexp_replace("term", " months", "")).cast(IntegerType()))

# Sonuçları gösterme
df.show()
# Out:
# +----+--------+-----------+-----------+
# |term|int_rate|installment|loan_status|
# +----+--------+-----------+-----------+
# |  36|   13.56|      84.92|    Current|
# |  60|   18.94|     777.23|    Current|
# |  36|   17.97|     180.69|    Current|
# |  36|   18.94|     146.51|    Current|
# |  60|   16.14|     731.78|    Current|
# |  36|   15.02|     192.45|    Current|
# |  36|   17.97|      72.28|    Current|
# |  36|   13.56|     203.79|    Current|
# |  36|   17.97|     180.69|    Current|
# |  36|   14.47|     206.44|    Current|
# |  36|   22.35|     211.05|    Current|
# |  60|   11.31|     613.13|    Current|
# |  36|    8.19|     351.95|    Current|
# |  36|   17.97|      234.9|    Current|
# |  60|   12.98|     500.35|    Current|
# |  36|   16.14|      123.3|    Current|
# |  36|   12.98|      235.8|    Current|
# |  60|   16.91|     620.11|    Current|
# |  60|   20.89|     431.87|    Current|
# |  60|   14.47|     305.67|    Current|
# +----+--------+-----------+-----------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import when, expr

# Spark oturumu başlatma
spark = SparkSession.builder.appName("LabelEncoding").getOrCreate()


df = df.withColumn("loan_status", when(df["loan_status"] == "Fully Paid", 0)
                                    .when(df["loan_status"] == "Charged Off", 1))

# Sonuçları gösterme
df.show()
# Out:
# +----+--------+-----------+-----------+
# |term|int_rate|installment|loan_status|
# +----+--------+-----------+-----------+
# |  36|   13.56|      84.92|       null|
# |  60|   18.94|     777.23|       null|
# |  36|   17.97|     180.69|       null|
# |  36|   18.94|     146.51|       null|
# |  60|   16.14|     731.78|       null|
# |  36|   15.02|     192.45|       null|
# |  36|   17.97|      72.28|       null|
# |  36|   13.56|     203.79|       null|
# |  36|   17.97|     180.69|       null|
# |  36|   14.47|     206.44|       null|
# |  36|   22.35|     211.05|       null|
# |  60|   11.31|     613.13|       null|
# |  36|    8.19|     351.95|       null|
# |  36|   17.97|      234.9|       null|
# |  60|   12.98|     500.35|       null|
# |  36|   16.14|      123.3|       null|
# |  36|   12.98|      235.8|       null|
# |  60|   16.91|     620.11|       null|
# |  60|   20.89|     431.87|       null|
# |  60|   14.47|     305.67|       null|
# +----+--------+-----------+-----------+
# only showing top 20 rows

# %%
from pyspark.sql import SparkSession

# Spark oturumu başlatma
spark = SparkSession.builder.appName("DropNullRows").getOrCreate()


# NaN içeren satırları silme
df = df.na.drop()

# Sonuçları gösterme
df.show()
# Out:
# +----+--------+-----------+-----------+
# |term|int_rate|installment|loan_status|
# +----+--------+-----------+-----------+
# |  36|   22.35|    1151.16|          0|
# |  60|   16.14|     975.71|          0|
# |  36|    7.56|     622.68|          0|
# |  36|   11.31|     147.99|          0|
# |  36|   27.27|     345.18|          0|
# |  60|   17.97|     507.55|          0|
# |  36|   11.31|     217.05|          0|
# |  36|   13.56|      84.92|          0|
# |  36|   17.97|     144.55|          0|
# |  36|    8.19|      84.85|          0|
# |  36|    23.4|      38.92|          0|
# |  36|    7.56|     467.01|          0|
# |  36|    7.56|     249.08|          0|
# |  36|    7.56|     155.67|          0|
# |  36|    7.56|     403.19|          0|
# |  60|   12.98|     237.67|          0|
# |  60|   26.31|     602.49|          0|
# |  60|   12.98|     227.43|          0|
# |  36|   10.33|     941.87|          0|
# |  36|   13.56|      33.97|          0|
# +----+--------+-----------+-----------+
# only showing top 20 rows

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# Spark oturumunu başlatın
spark = SparkSession.builder.appName("DataTypeCheck").getOrCreate()


# Veri tiplerini kontrol edin
df.printSchema()

# Özellikle belirli bir sütunun veri türünü kontrol edin (örneğin "term")
term_data_type = df.schema["term"].dataType
print(f"Veri Türü (term): {term_data_type}")

int_rate_data_type = df.schema["int_rate"].dataType
print(f"Veri Türü (int_rate): {int_rate_data_type}")

installment_data_type = df.schema["installment"].dataType
print(f"Veri Türü (installment): {installment_data_type}")

loan_status_data_type = df.schema["label"].dataType
print(f"Veri Türü (label): {loan_status_data_type}")
# Out:
# root
#  |-- term: integer (nullable = true)
#  |-- int_rate: double (nullable = true)
#  |-- installment: double (nullable = true)
#  |-- label: integer (nullable = true)
#  |-- features: vector (nullable = true)
#  |-- features1: vector (nullable = true)
#
# Veri Türü (term): IntegerType
# Veri Türü (int_rate): DoubleType
# Veri Türü (installment): DoubleType
# Veri Türü (label): IntegerType

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import rand

# Spark oturumunu başlatın
spark = SparkSession.builder.appName("SampleData").getOrCreate()


# Veri kümesini yüzde 20'sine küçültün
df = df.sample(fraction=0.2, seed=42)

# Örnekleme sonucunu görüntüleyin
df.show()
# Out:
# +----+--------+-----------+-----+-------------------+-------------------+
# |term|int_rate|installment|label|           features|          features1|
# +----+--------+-----------+-----+-------------------+-------------------+
# |  36|   13.56|      84.92|    0| [36.0,13.56,84.92]| [36.0,13.56,84.92]|
# |  60|   26.31|     602.49|    0|[60.0,26.31,602.49]|[60.0,26.31,602.49]|
# |  36|   10.33|     941.87|    0|[36.0,10.33,941.87]|[36.0,10.33,941.87]|
# |  36|    11.8|     298.07|    0| [36.0,11.8,298.07]| [36.0,11.8,298.07]|
# |  60|    8.19|     325.88|    0| [60.0,8.19,325.88]| [60.0,8.19,325.88]|
# |  36|    8.19|     314.25|    0| [36.0,8.19,314.25]| [36.0,8.19,314.25]|
# |  36|   19.92|     111.37|    0|[36.0,19.92,111.37]|[36.0,19.92,111.37]|
# |  60|   10.33|     256.92|    0|[60.0,10.33,256.92]|[60.0,10.33,256.92]|
# |  60|   15.02|     476.01|    0|[60.0,15.02,476.01]|[60.0,15.02,476.01]|
# |  36|   12.98|     370.53|    0|[36.0,12.98,370.53]|[36.0,12.98,370.53]|
# |  60|    11.8|     885.75|    0| [60.0,11.8,885.75]| [60.0,11.8,885.75]|
# |  36|   20.89|     225.72|    0|[36.0,20.89,225.72]|[36.0,20.89,225.72]|
# |  36|    8.19|    1099.85|    0|[36.0,8.19,1099.85]|[36.0,8.19,1099.85]|
# |  36|    7.56|     149.45|    0| [36.0,7.56,149.45]| [36.0,7.56,149.45]|
# |  60|   10.72|     216.04|    0|[60.0,10.72,216.04]|[60.0,10.72,216.04]|
# |  36|    8.81|    1268.46|    0|[36.0,8.81,1268.46]|[36.0,8.81,1268.46]|
# |  60|   19.92|      317.4|    0| [60.0,19.92,317.4]| [60.0,19.92,317.4]|
# |  60|   17.97|     304.53|    0|[60.0,17.97,304.53]|[60.0,17.97,304.53]|
# |  60|   14.47|     395.02|    0|[60.0,14.47,395.02]|[60.0,14.47,395.02]|
# |  60|   14.47|     235.13|    0|[60.0,14.47,235.13]|[60.0,14.47,235.13]|
# +----+--------+-----------+-----+-------------------+-------------------+
# only showing top 20 rows

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("MyApp") \
    .config("spark.executor.cores", "4") \
    .config("spark.executor.memory", "8g") \
    .getOrCreate()

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import MultilayerPerceptronClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

spark = SparkSession.builder.appName("LoanStatusPrediction").getOrCreate()

# feature_columns = ["term", "int_rate", "installment"]
assembler = VectorAssembler(inputCols=feature_columns, outputCol="features")
df = assembler.transform(df)

# Veri setini eğitim ve test olarak bölelim
train_data, test_data = df.randomSplit([0.8, 0.2], seed=42)

# Yapay sinir ağı modelini tanımlayın
layers = [len(feature_columns), 5, 2]  # Giriş, Gizli Katman, Çıkış
classifier = MultilayerPerceptronClassifier(layers=layers, seed=42)

# Modeli eğitin
model = classifier.fit(train_data)

# Test verisi üzerinde tahminler yapın
predictions = model.transform(test_data)

# Sınıflandırma performansını değerlendirin
evaluator = MulticlassClassificationEvaluator(labelCol="loan_status", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
print("Model Accuracy:", accuracy)
# Out:
# [Stage 2672:===================>                                   (5 + 9) / 14]
# Model Accuracy: 0.7987461297332641
# [Stage 2672:==============================================>       (12 + 2) / 14]
